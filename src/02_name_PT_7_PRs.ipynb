# %%
import pandas as pd
from pathlib import Path
import csd as c

# %% [markdown]
# ## Find counter prices

# %%
df = c.pull_counter_price()
# Out:
# C:\Users\franc\miniconda3\envs\work\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# run_query took 14.946173667907715s

# %%
df.head()
# Out:
#    pdrecno     startdt       enddt  levelcd  prcmult_1       prod  \
# 0     5847  2007-06-22  2029-12-30        7      205.0  01-ICP578
# 1    90378  2022-10-13        None        7      275.0      14098
# 2      400  2021-06-02  2039-12-30        7      190.0   55101001
# 3      401  2021-06-02  2039-12-30        7      200.0   55101002
# 4    63800  2021-06-02  2029-12-30        7      200.0   55201001
#
#                  description                 refer  status  lastuseddt
# 0                       None  Level 7 Pricing Load  Active  2023-01-23
# 1  1/2  VINYL J-Channel WHT           AR 12/20/22   Active  2022-12-20
# 2   REDUCING TEE 8X8X3 26GA.      6400 FIX 8/16/21  Active  2021-09-23
# 3   REDUCING TEE 4X4X3 26GA.      6400 FIX 8/16/21  Active  2021-09-23
# 4     5" VERT OVAL 90D ELBOW      6400 FIX 8/16/21  Active  2022-07-12

# %% [markdown]
# ## <span style="color:red"> Change vendor name in last part of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_product_info.csv'
products_df = pd.read_csv(loc)

# %%
products_df.head()
# Out:
#    whse  vendno            name      prod                 descrip_1 descrip_2  \
# 0   801   86125  MERFISH UNITED   BLK2103       1-1/4"X21' TC BLACK      PIPE
# 1   801   86125  MERFISH UNITED   BLK2100  1/2" X 21' TC BLACK PIPE       NaN
# 2   801   86125  MERFISH UNITED   CPF3002    1"X20' "L" COPPER PIPE       NaN
# 3   801   86125  MERFISH UNITED  CPF3002A    1"X10' "L" COPPER PIPE       NaN
# 4   801   86125  MERFISH UNITED   CPF3015    2"X20' "M" COPPER PIPE       NaN
#
#   mfgprod           vendprod pricetype  prodcat  ... replcost  replcostdt  \
# 0     NaN  WIBTCA53A0120140S       635     6350  ...    54.87  2021-08-16
# 1     NaN  WIBTCA53A0040109S       635     6350  ...    17.24  2021-09-17
# 2     NaN                177       638     6380  ...    98.74  2021-11-08
# 3     NaN                166       638     6380  ...    44.19  2021-05-06
# 4     NaN                207       638     6380  ...   192.82  2021-08-16
#
# ...

# %%
PT_7_PRs_df = pd.DataFrame()

for item in products_df['prod']:
    partial_df = df.loc[df['prod'] == item]
    PT_7_PRs_df = pd.concat([PT_7_PRs_df,partial_df])

# %%
PT_7_PRs_df.head()
# Out:
#       pdrecno     startdt       enddt  levelcd  prcmult_1      prod  \
# 2615     1459  2021-05-21  2029-12-30        7  203.00000   BLK2103
# 2610    73303  2021-09-17        None        7  450.00000   BLK2100
# 3774     2470  2021-05-06  2029-12-30        7  161.29032   CPF3002
# 3775    75502  2021-11-08  2029-12-30        7  161.29032  CPF3002A
# 3784     2479  2021-04-14  2029-12-30        7  161.29032   CPF3015
#
#                     description             refer  status  lastuseddt
# 2615   1-1/4"X21' TC BLACK PIPE     HVAC FIX 8/19  Active  2021-09-03
# 2610  1/2" X 21' TC BLACK PIPE   WP ADDED 9/17/21  Active        None
# 3774    1"X20' "L" COPPER PIPE      HVAC FIX 8/19  Active  2022-09-14
# 3775    1"X10' "L" COPPER PIPE   DS Added 11/8/21  Active  2021-11-12
# 3784    2"X20' "M" COPPER PIPE      HVAC FIX 8/19  Active        None

# %%
PT_7_PRs_df.shape
# Out:
# (75, 10)

# %% [markdown]
# ## <span style="color:red"> Change vendor name in last part of vendor path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_PT_7_PRs.csv'
PT_7_PRs_df.to_csv(loc, index=False)
