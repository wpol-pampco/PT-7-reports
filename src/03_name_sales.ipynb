# %% [markdown]
# # Identify sales

# %%
import pandas as pd
from pathlib import Path
import csd as c

# %%
loc = Path.cwd().parent.parent / 'auxiliary' / 'data' / 'invoice_data_2_in-scope.csv'
inv_df = pd.read_csv(loc)

# %% [markdown]
# ## All invoice lines of sales

# %% [markdown]
# ## <span style="color:red"> Change vendor number(s)

# %%
sales_df = inv_df[ (inv_df['vendno'] == 18821) | (inv_df['vendno'] == 86125) ]

# %%
sales_df.to_clipboard()

# %%
sales_df.head()
# Out:
#       whse    orderno  ordersuf  lineno   invoicedt  custno  \
# 98     101  911007174         0       1  2022-03-04  100046
# 118    101  911007696         0       6  2022-03-04  100046
# 546    101  911010559         0       1  2021-12-01  101252
# 611    101  911010570         0      12  2021-12-01  101238
# 1000   101  911010708         0       1  2021-12-02  101233
#
#                             custname    item                  itemdesc unit  \
# 98         AIR PRO HEATING & COOLING  PVC500    3"X10' PVC SCH40 PIPE    EA
# 118        AIR PRO HEATING & COOLING  PVC50A    2"X10' PVC SCH40 PIPE    EA
# 546           TOTAL COMFORT HVAC LLC  PVC50A    2"X10' PVC SCH40 PIPE    EA
# 611   FUSION HEATING AND COOLING LLC  PVC251  3/4"X10' PVC SCH40 PIPE    EA
# 1000                        G-W-HVAC  PVC251  3/4"X10' PVC SCH40 PIPE    EA
#
#       ...  pdrecno   vendno  arpvendno  xcost_adj        GP$    Margin  \
# 98    ...    67052  18821.0        0.0  207.15430  299.94570  0.591492
# 118   ...     9373  18821.0        0.0   21.32881    4.15119  0.162920
# 546   ...     9373  18821.0        0.0  107.01576   57.02424  0.347624
# 611   ...    44625  18821.0        0.0   15.79500    9.34500  0.371718
# 1000  ...    44577  18821.0        0.0   26.32500   15.57500  0.371718
#
#         month Exclusion     whse_name  division
# 98    2022-03       NaN  Clifton HVAC      HVAC
# 118   2022-03       NaN  Clifton HVAC      HVAC
# 546   2021-12       NaN  Clifton HVAC      HVAC
# 611   2021-12       NaN  Clifton HVAC      HVAC
# 1000  2021-12       NaN  Clifton HVAC      HVAC
#
# [5 rows x 33 columns]

# %%
sales_df.columns
# Out:
# Index(['whse', 'orderno', 'ordersuf', 'lineno', 'invoicedt', 'custno',
#        'custname', 'item', 'itemdesc', 'unit', 'unitconv', 'units', 'unitcost',
#        'replcost', 'unitprice', 'netamt', 'returnfl', 'transtype', 'prod_type',
#        'prodcat', 'cat_descrip', 'rowpointer', 'priceorigcd', 'pdrecno',
#        'vendno', 'arpvendno', 'xcost_adj', 'GP$', 'Margin', 'month',
#        'Exclusion', 'whse_name', 'division'],
#       dtype='object')

# %% [markdown]
# ## Total sales by item and total customers

# %%
"""
group sales in two stages:
    first stage by 'item' and 'custno' with 'units' aggregated by sum
    second stage by 'item' aggregating 'custno' by count and 'units' by sum
the two stages of process let us count # of customers and get total sales of each item
"""
agg_sales_pre_df = sales_df.groupby(by=['item','itemdesc','custno'],as_index=False).agg({'units':'sum','netamt':'sum','xcost_adj':'sum'})

# %%
agg_sales_pre_df.to_clipboard(index=False)

# %%
agg_sales_pre_df
# Out:
#          item                  itemdesc  custno  units   netamt   xcost_adj
# 0    CPF3000A    1/2" X 10' "L" COPPER   101013   24.0   619.68   475.36500
# 1     CPF3001  3/4"X20' "L" COPPER PIPE  101013   11.0  1079.85   768.48918
# 2    CPF3001A  3/4"X10' "L" COPPER PIPE  101013  115.0  5367.85  3905.64495
# 3     CPF3011  3/4"X20' "M" COPPER PIPE  101013    8.0   501.04   311.77415
# 4     CPF3011  3/4"X20' "M" COPPER PIPE  101035    2.0   128.66    60.89800
# ..        ...                       ...     ...    ...      ...         ...
# 348    PVC50A    2"X10' PVC SCH40 PIPE   110465    2.0    66.40    42.00000
# 349    PVC50A    2"X10' PVC SCH40 PIPE   111261    2.0    62.12    42.65762
# 350    PVC50A    2"X10' PVC SCH40 PIPE   111965    2.0    66.40    38.69048
# 351    PVC50A    2"X10' PVC SCH40 PIPE   112441    3.0    91.80    57.20244
# 352    PVC50A    2"X10' PVC SCH40 PIPE   112601    1.0    28.56    19.06748
#
# [353 rows x 6 columns]

# %%
agg_sales_df = agg_sales_pre_df.groupby(by=['item','itemdesc'],as_index=False).agg({'custno':'count','units':'sum','netamt':'sum','xcost_adj':'sum'}).rename(columns={'custno':'total cust\'s','units':'total units'})

# %%
agg_sales_df['total margin'] = round( 100*(agg_sales_df['netamt'] - agg_sales_df['xcost_adj']) / agg_sales_df['netamt'], 2)

# %%
agg_sales_df = agg_sales_df.drop(columns=['netamt','xcost_adj'])

# %%
agg_sales_df.to_clipboard(index=False)

# %% [markdown]
# ## Sales on overrides

# %%
overrides_df = sales_df.loc[sales_df['priceorigcd'] == 'O']

# %%
overrides_df.drop(columns=['ordersuf','lineno','unit','unitconv','arpvendno','month','Exclusion','cat_descrip','whse_name','division'])
# Out:
#         whse    orderno   invoicedt  custno                   custname  \
# 3757     101  911011538  2021-12-10  100088           A. CIAVAGLIA INC
# 16280    101  911015612  2022-02-01  101744               RB KRAFT LLC
# 19693    101  911016580  2022-02-11  101223               FERRETO HVAC
# 22202    101  911017337  2022-02-19  102774        ADVANCED MECHANICAL
# 31640    101  911020161  2022-03-21  105145   SANTIAGO'S HVAC SERVICES
# ...      ...        ...         ...     ...                        ...
# 260621   801  981010608  2022-10-03  101354              TOTAL COMFORT
# 260980   801  981010706  2022-10-06  101013        BELL MECHANICAL LLC
# 261132   801  981010754  2022-10-07  101000  A & G INSTALLATIONS, INC.
# 262161   801  981011114  2022-10-20  101046   R.J.C. HEATING & COOLING
# 262619   801  981011278  2022-10-27  101013        BELL MECHANICAL LLC
#
#             item                        itemdesc  units  unitcost  replcost  \
# 3757      PVC251        3/4"X10' PVC SCH40 PIPE    40.0   5.26500      6.42
# 16280     PVC500          3"X10' PVC SCH40 PIPE     1.0  20.71552     40.08
# 19693     PVC50A          2"X10' PVC SCH40 PIPE     1.0  21.32881     20.04
# 22202     PVC50A          2"X10' PVC SCH40 PIPE     3.0  21.32881     20.04
# 31640     PVC251        3/4"X10' PVC SCH40 PIPE     4.0   6.33960      6.72
# ...          ...                             ...    ...       ...       ...
# 260621   CPF3110  1/4" X 50' REFRIG. COIL COPPER    1.0  40.06200     39.65
# 260980  CPF3001A        3/4"X10' "L" COPPER PIPE   30.0  32.47000     30.49
# 261132   CPF3023    3/4"ODX20' "ACR" COPPER PIPE    3.0  65.16406     65.15
# 262161  CPF3011A        3/4"X10' "M" COPPER PIPE    2.0  24.91086     22.17
# 262619  CPF3001A        3/4"X10' "L" COPPER PIPE   10.0  33.15150     30.49
#
#         ...  transtype  prod_type  prodcat  \
# 3757    ...         SO    stocked     7000
# 16280   ...         CS    stocked     7000
# 19693   ...         CS    stocked     7000
# 22202   ...         CS    stocked     7000
# 31640   ...         CS    stocked     7000
# ...     ...        ...        ...      ...
# 260621  ...         SO    stocked     6380
# 260980  ...         SO    stocked     6380
# 261132  ...         SO    stocked     6380
# 262161  ...         SO    stocked     6380
# 262619  ...         SO    stocked     6380
#
#                                   rowpointer priceorigcd  pdrecno   vendno  \
# 3757    f3f70746-ba81-659b-8c14-43ae707054c5           O        0  18821.0
# 16280   99af3962-7f75-29a0-8f14-6cf158c9ffd7           O    67052  18821.0
# 19693   cda1f5ef-16b1-ed9a-9014-678e8838715c           O     9373  18821.0
# 22202   9c7924c6-4f7a-cfab-9114-9f0bc86853a4           O     9373  18821.0
# 31640   afba2a60-b0aa-6aa1-9214-86e3784a19e1           O    45489  18821.0
# ...                                      ...         ...      ...      ...
# 260621  946f0448-d2f6-8d8a-9e14-7be8a00bb0f1           O        0  86125.0
# 260980  93970650-8a09-47bd-9f14-aa0df06daa82           O    63025  86125.0
# 261132  e2cd53ed-fb64-049a-9f14-b72908705ab2           O    63023  86125.0
# 262161  b08fc032-0573-0481-9f14-c8f5b8f74f11           O    63033  86125.0
# 262619  a7b479b4-3403-a9b7-a014-6957a050c205           O    63025  86125.0
#
#         xcost_adj        GP$    Margin
# 3757    210.60000  107.40000  0.337736
# 16280    20.71552   36.54448  0.638220
# 19693    21.32881    5.39119  0.201766
# 22202    63.98643   11.16357  0.148550
# 31640    25.35840   11.20160  0.306389
# ...           ...        ...       ...
# 260621   40.06200   16.58800  0.292816
# 260980  974.10000  477.90000  0.329132
# 261132  195.49218   77.53782  0.283990
# 262161   49.82172   16.57828  0.249673
# 262619  331.51500  152.48500  0.315052
#
# [93 rows x 23 columns]

# %%
agg_overrides_df = overrides_df.groupby(by=['item'],as_index=False).agg({'orderno':'count','units':'sum'}).rename(columns={'orderno':'no. of override orders','units':'units overriden'})

# %%
agg_overrides_df
# Out:
#         item  no. of override orders  units overriden
# 0   CPF3000A                       1             10.0
# 1    CPF3001                       1              5.0
# 2   CPF3001A                       5             95.0
# 3   CPF3011A                       3             24.0
# 4   CPF3012A                       1              2.0
# 5    CPF3013                       1              1.0
# 6    CPF3023                      13             50.0
# 7    CPF3110                       3              3.0
# 8    CPF3112                      11             80.0
# 9    CPF3114                       1              2.0
# 10   CPF3115                       4             36.0
# 11   CPF3116                       3             39.0
# 12    PVC251                      11             99.0
# 13     PVC26                       6             34.0
# 14    PVC401                       2              3.0
# 15      PVC5                       3             44.0
# 16    PVC500                       6             41.0
# 17    PVC50A                      18             94.0

# %% [markdown]
# ## Total PT 7 sales (no overrides)

# %% [markdown]
# ## <span style="color:red"> Change vendor name in last part of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_PT_7_PRs.csv'
PT_7_PRs = pd.read_csv(loc)

# %%
PT_7_PRs = PT_7_PRs.drop_duplicates()

# %%
PT_7_sales_by_PR_df = sales_df.merge(PT_7_PRs[['prod','pdrecno']], how='inner', left_on=['item','pdrecno'], right_on=['prod','pdrecno'])

# %%
PT_7_sales_by_PR_df.head()
# Out:
#    whse    orderno  ordersuf  lineno   invoicedt  custno  \
# 0   101  911007174         0       1  2022-03-04  100046
# 1   101  911013280         0       6  2022-01-04  101164
# 2   101  911014036         0       5  2022-01-13  102547
# 3   101  911014994         0       2  2022-02-15  100278
# 4   101  911015612         0       1  2022-02-01  101744
#
#                        custname    item                itemdesc unit  ...  \
# 0     AIR PRO HEATING & COOLING  PVC500  3"X10' PVC SCH40 PIPE    EA  ...
# 1                  CAP HVAC INC  PVC500  3"X10' PVC SCH40 PIPE    EA  ...
# 2                     AIR ZONES  PVC500  3"X10' PVC SCH40 PIPE    EA  ...
# 3  ENVIRONMENTAL CLIMATE CONTRL  PVC500  3"X10' PVC SCH40 PIPE    EA  ...
# 4                  RB KRAFT LLC  PVC500  3"X10' PVC SCH40 PIPE    EA  ...
#
#     vendno  arpvendno  xcost_adj        GP$    Margin    month  Exclusion  \
# 0  18821.0        0.0  207.15430  299.94570  0.591492  2022-03        NaN
# 1  18821.0        0.0  103.57660  207.07340  0.666581  2022-01        NaN
# 2  18821.0        0.0   62.14656  124.24344  0.666578  2022-01        NaN
# 3  18821.0        0.0   41.43104   82.82896  0.666578  2022-02        NaN
# 4  18821.0        0.0   20.71552   36.54448  0.638220  2022-02        NaN
#
#       whse_name division    prod
# 0  Clifton HVAC     HVAC  PVC500
# 1  Clifton HVAC     HVAC  PVC500
# 2  Clifton HVAC     HVAC  PVC500
# 3  Clifton HVAC     HVAC  PVC500
# 4  Clifton HVAC     HVAC  PVC500
#
# [5 rows x 34 columns]

# %%
PT_7_sales_by_PR_df.shape
# Out:
# (582, 34)

# %%
PT_7_sales_by_PR_df['margin by replcost'] = (PT_7_sales_by_PR_df['netamt'] - PT_7_sales_by_PR_df['replcost']*PT_7_sales_by_PR_df['units']) / PT_7_sales_by_PR_df['netamt']

# %%
# drop unnecessary columns
PT_7_sales_by_PR_df = PT_7_sales_by_PR_df.drop(columns=['orderno','ordersuf','lineno','unit','unitconv','returnfl','prod_type','prodcat','cat_descrip','rowpointer','arpvendno','Exclusion'])

# %%
# inspect output
PT_7_sales_by_PR_df.to_clipboard(index=False)

# %%
PT_7_no_overs_df = PT_7_sales_by_PR_df.loc[ PT_7_sales_by_PR_df['priceorigcd'] == '7']

# %%
# inspect output
PT_7_no_overs_df.to_clipboard(index=False)

# %%
"""
group sales in two stages:
    first stage by 'item' and 'custno' with 'units' aggregated by sum
    second stage by 'item' aggregating 'custno' by count and 'units' by sum
the two stages of process let us count # of customers and get total sales of each item
"""
PT_7_no_overs_agg_pre_df = PT_7_no_overs_df.groupby(by=['item','custno'],as_index=False).agg({'units':'sum'})

# %%
PT_7_no_overs_agg_pre_df.to_clipboard(index=False)

# %%
PT_7_no_overs_agg_pre_df.loc[PT_7_no_overs_agg_pre_df.duplicated(subset=['item','custno'])]
# Out:
# Empty DataFrame
# Columns: [item, custno, units]
# Index: []

# %%
PT_7_no_overs_agg_df = PT_7_no_overs_agg_pre_df.groupby(by=['item'],as_index=False).agg({'custno':'count','units':'sum'}).rename(columns={'custno':'PT 7 cust\'s', 'units':'PT 7 units'})

# %%
PT_7_no_overs_agg_df
# Out:
#        item  PT 7 cust's  PT 7 units
# 0   CPF3011            2         9.0
# 1   CPF3020            1         1.0
# 2   CPF3023            1         1.0
# 3   CPF3024            1         1.0
# 4   CPF3110            1         1.0
# 5   CPF3114            1         1.0
# 6   CPF3116            1        10.0
# 7    PVC251           99      1171.0
# 8     PVC26            8        38.0
# 9    PVC401            1        29.0
# 10     PVC5            3        17.0
# 11   PVC500           12       100.0
# 12   PVC50A           47       868.0

# %%
# make cumulative percentage stats
PT_7_no_overs_quartiles_df = PT_7_no_overs_agg_pre_df[['item','units']].groupby('item').quantile(q=[.5,.75,1],interpolation='midpoint')

# %%
PT_7_no_overs_quartiles_df.head()
# Out:
#               units
# item
# CPF3011 0.50    4.5
#         0.75    4.5
#         1.00    8.0
# CPF3020 0.50    1.0
#         0.75    1.0

# %%
PT_7_no_overs_quartiles_df = PT_7_no_overs_quartiles_df.reset_index()

# %%
# data frame of quartiles of sales per customer
quartile_df = pd.DataFrame([ [prod,tuple(PT_7_no_overs_quartiles_df.loc[PT_7_no_overs_quartiles_df['item'] == prod]['units'].tolist())] for prod in PT_7_no_overs_quartiles_df['item'].unique()], columns=['item','PT 7 quartiles'])

# %%
quartile_df
# Out:
#        item      PT 7 quartiles
# 0   CPF3011     (4.5, 4.5, 8.0)
# 1   CPF3020     (1.0, 1.0, 1.0)
# 2   CPF3023     (1.0, 1.0, 1.0)
# 3   CPF3024     (1.0, 1.0, 1.0)
# 4   CPF3110     (1.0, 1.0, 1.0)
# 5   CPF3114     (1.0, 1.0, 1.0)
# 6   CPF3116  (10.0, 10.0, 10.0)
# 7    PVC251  (4.0, 11.0, 238.0)
# 8     PVC26    (2.5, 4.0, 22.0)
# 9    PVC401  (29.0, 29.0, 29.0)
# 10     PVC5    (5.0, 8.0, 11.0)
# 11   PVC500    (5.0, 9.0, 41.0)
# 12   PVC50A  (4.0, 11.0, 511.0)

# %% [markdown]
# # Standard cost, multiplier, and standard price

# %% [markdown]
# ## <span style="color:red"> Change the vendor name at end of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_product_info.csv'
cost_data_df = pd.read_csv(loc)

# %%
cost_data_df_subset = cost_data_df[['prod','stndcost','prcmult_1','stndprice']].drop_duplicates()

# %%
"""
make sure there are no mismatches in standard costs across warehouses
although warehouses are excluded in cost_data_df
there are multiplicities of entries corresponding to each warehouse
"""
cost_data_df_subset.loc[cost_data_df_subset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [prod, stndcost, prcmult_1, stndprice]
# Index: []

# %%
cost_data_df.columns
# Out:
# Index(['whse', 'vendno', 'name', 'prod', 'descrip_1', 'descrip_2', 'mfgprod',
#        'vendprod', 'pricetype', 'prodcat', 'prodcat_descrip', 'unitstock',
#        'unitsell', 'unitconv', 'listprice', 'avgcost', 'lastcost', 'replcost',
#        'replcostdt', 'stndcost', 'stndcostdt', 'priceonty', 'prcmult_1',
#        't12m_sales', 'qtyonhand', 'qtyonorder', 'stndprice'],
#       dtype='object')

# %% [markdown]
# ## <span style="color:red"> Change vendor number(s)

# %%
# pick out cost data for our vendor
specific_cost_data_df = cost_data_df.loc[ ((cost_data_df['vendno'] == 18821) | (cost_data_df['vendno'] == 86125)) ][['prod','descrip_1','descrip_2','stndcost','prcmult_1','stndprice']].drop_duplicates()

# %%
specific_cost_data_df['stndmargin'] = round((specific_cost_data_df['prcmult_1']*100 - 100) / specific_cost_data_df['prcmult_1'], 2)

# %%
specific_cost_data_df
# Out:
#         prod                 descrip_1        descrip_2  stndcost  prcmult_1  \
# 0    CPF3012    1"X20' "M" COPPER PIPE              NaN   75.6800   2.310000
# 1   CPF3013A     1-1/4"X10' "M" COPPER             PIPE   50.1800   1.000000
# 2    CPF3115     3/4"X50' REFRIG. COIL           COPPER  126.6700   1.000000
# 3    CPF3001       3/4"X20' "L" COPPER             PIPE   68.0900   1.000000
# 4    CPF3110   1/4" X 50' REFRIG. COIL           COPPER   39.6500   1.000000
# 5    CPF3022   5/8"ODX20' "ACR" COPPER             PIPE   48.2900   1.000000
# 6   CPF3012A    1"X10' "M" COPPER PIPE              NaN   37.8400   1.000000
# 7    CPF3021         1/2"OD X 20' "ACR      COPPER PIPE   37.6800   1.000000
# 8   CPF3112B    3/8"X50' ORANGE COATED              NaN   60.5300   2.000000
# 9   BLK2101A    3/4"X10' TC BLACK PIPE              NaN   18.0900   1.910000
# 10  CPF3001A       3/4"X10' "L" COPPER             PIPE   30.4900   1.000000
# 11  CPF3002A    1"X10' "L" COPPER PIPE              NaN   44.1900   1.702874
# 12   CPF3111    5/16"X50' REFRIG. COIL           COPPER   27.2800   2.390000
# 13   CPF3002    1"X20' "L" COPPER PIPE              NaN   98.7400   1.000000
# 14   CPF3011       3/4"X20' "M" COPPER             PIPE   49.5200   1.000000
# 15   CPF3113   1/2" X 50' REFRIG. COIL           COPPER   79.7400   4.270000
# 16   CPF3117   1-1/8"X50' REFRIG. COIL           COPPER  247.9500   2.270000
# 17  CPF3113B  1/2" X 50' ORANGE COATED              NaN  101.3700   2.110000
# 18   CPF3114     5/8"X50' REFRIG. COIL           COPPER  106.7200   2.070000
# 19   CPF3023   3/4"ODX20' "ACR" COPPER             PIPE   65.1500   1.000000
# 20   CPF3015    2"X20' "M" COPPER PIPE              NaN  192.8200   2.000000
# 21   CPF3025         1-1/8"ODX20' "ACR      COPPER PIPE  110.8900   1.000000
# 22   CPF3000     1/2 "X 20' "L" COPPER             PIPE   41.7900   1.000000
# 23   CPF3024   7/8"ODX20' "ACR" COPPER             PIPE   77.1500   1.000000
# 24  CPF3000A     1/2" X 10' "L" COPPER              NaN   19.8800   1.000000
# 25   CPF3020   3/8"ODX20' "ACR" COPPER             PIPE   24.9900   1.000000
# 26  CPF3011A       3/4"X10' "M" COPPER             PIPE   22.1700   1.000000
# 27   CPF3112     3/8"X50' REFRIG. COIL           COPPER   56.0500   1.000000
# 28   CPF3100       1/4" X 60' "L" COIL  COPPER (3/8"OD)   39.2000   2.000000
# 29   CPF3014     1-1/2"X20' "M" COPPER             PIPE  107.9100   2.000000
# 30  CPF3102A       3/4"X60' "L" COPPER             COIL   54.3300   2.000000
# 31   CPF3026         1-3/8"ODX20' "ACR      COPPER PIPE  147.8700   1.000000
# 32   CPF3013     1-1/4"X20' "M" COPPER             PIPE  112.1200   2.260000
# 33   BLK2101    3/4"X21' TC BLACK PIPE              NaN   34.9800   2.460000
# 34   BLK2103       1-1/4"X21' TC BLACK             PIPE   54.8700   2.030000
# 35  BLK2102A      1"X10' TC BLACK PIPE              NaN   23.1400   1.000000
# 36  BLK2100A  1/2" X 10' TC BLACK PIPE              NaN   17.2400   4.550000
# 37   BLK2100  1/2" X 21' TC BLACK PIPE              NaN   17.2400   4.500000
# 38   CPF3027         1-5/8"ODX20' "ACR      COPPER PIPE  150.2500   1.000000
# 39   CPF3116     7/8"X50' REFRIG. COIL           COPPER  188.9900   1.000000
# 40   CPF3006     2-1/2"X20' "L" COPPER             PIPE  119.4100   2.000000
# 41    PVC500     3"X10' PVC SCH40 PIPE              NaN   43.0848   1.550000
# 42    PVC220    2"X20' PVC SCHEDULE 40             PIPE   17.5300   2.460000
# 43     PVC50     2"X20' PVC SCH40 PIPE              NaN   10.7100   1.650000
# 44      PVC5     3"X20' PVC SCH40 PIPE              NaN   29.3300   1.550000
# 45    PVC320    3"X20' PVC SCHEDULE 40             PIPE   29.3000   2.750000
# 46    PVC420    4"X20' PVC SCHEDULE 40             PIPE   41.3000   2.740000
# 47     PVC25   3/4"X20' PVC SCH40 PIPE              NaN    3.4272   1.550000
# 49     PVC25   3/4"X20' PVC SCH40 PIPE              NaN    5.5900   1.550000
# 50    PVC251   3/4"X10' PVC SCH40 PIPE              NaN    6.8544   1.550000
# 54     PVC50     2"X20' PVC SCH40 PIPE              NaN   14.6100   1.650000
# 55    PVC402      1-1/4"X10' SCH40 PVC             PIPE    5.1000   3.990000
# 56     PVC26   3/4"X10' SCH40 PVC PIPE              NaN    6.1200   1.000000
# 59      PVC5     3"X20' PVC SCH40 PIPE              NaN   21.5424   1.550000
# 61    PVC50A     2"X10' PVC SCH40 PIPE              NaN   21.4200   1.550000
# 71    PVC401     1"X10' PVC SCH40 PIPE              NaN   10.7712   1.650000
#
#     stndprice  stndmargin
# 0      174.82       56.71
# 1       50.18        0.00
# 2      126.67        0.00
# 3       68.09        0.00
# 4       39.65        0.00
# 5       48.29        0.00
# 6       37.84        0.00
# 7       37.68        0.00
# 8      121.06       50.00
# 9       34.55       47.64
# 10      30.49        0.00
# 11      75.25       41.28
# 12      65.20       58.16
# 13      98.74        0.00
# 14      49.52        0.00
# 15     340.49       76.58
# 16     562.85       55.95
# 17     213.89       52.61
# 18     220.91       51.69
# 19      65.15        0.00
# 20     385.64       50.00
# 21     110.89        0.00
# 22      41.79        0.00
# 23      77.15        0.00
# 24      19.88        0.00
# 25      24.99        0.00
# 26      22.17        0.00
# 27      56.05        0.00
# 28      78.40       50.00
# 29     215.82       50.00
# 30     108.66       50.00
# 31     147.87        0.00
# 32     253.39       55.75
# 33      86.05       59.35
# 34     111.39       50.74
# 35      23.14        0.00
# 36      78.44       78.02
# 37      77.58       77.78
# 38     150.25        0.00
# 39     188.99        0.00
# 40     238.82       50.00
# 41      66.78       35.48
# 42      43.12       59.35
# 43      17.67       39.39
# 44      45.46       35.48
# 45      80.58       63.64
# 46     113.16       63.50
# 47       5.31       35.48
# 49       8.66       35.48
# 50      10.62       35.48
# 54      24.11       39.39
# 55      20.35       74.94
# 56       6.12        0.00
# 59      33.39       35.48
# 61      33.20       35.48
# 71      17.77       39.39

# %% [markdown]
# ## Put everything together

# %%
merge_1_df = agg_sales_df.merge(agg_overrides_df, how='left', on='item')

# %%
merge_2_df = merge_1_df.merge(PT_7_no_overs_agg_df, how='left', on='item')

# %%
merge_3_df = merge_2_df.merge(quartile_df, how='left', on='item')

# %%
merge_4_df = merge_3_df.merge(specific_cost_data_df, how='outer', left_on='item', right_on='prod')

# %%
final_df = merge_4_df.drop(columns='item')

# %%
final_df.columns
# Out:
# Index(['itemdesc', 'total cust's', 'total units', 'total margin',
#        'no. of override orders', 'units overriden', 'PT 7 cust's',
#        'PT 7 units', 'PT 7 quartiles', 'prod', 'descrip_1', 'descrip_2',
#        'stndcost', 'prcmult_1', 'stndprice', 'stndmargin'],
#       dtype='object')

# %%
final_df.head()
# Out:
#                    itemdesc  total cust's  total units  total margin  \
# 0    1/2" X 10' "L" COPPER            1.0         24.0         23.29
# 1  3/4"X20' "L" COPPER PIPE           1.0         11.0         28.83
# 2  3/4"X10' "L" COPPER PIPE           1.0        115.0         27.24
# 3  3/4"X20' "M" COPPER PIPE           3.0         11.0         41.77
# 4  3/4"X10' "M" COPPER PIPE           2.0         41.0         19.66
#
#    no. of override orders  units overriden  PT 7 cust's  PT 7 units  \
# 0                     1.0             10.0          NaN         NaN
# 1                     1.0              5.0          NaN         NaN
# 2                     5.0             95.0          NaN         NaN
# 3                     NaN              NaN          2.0         9.0
# 4                     3.0             24.0          NaN         NaN
#
#     PT 7 quartiles      prod              descrip_1 descrip_2  stndcost  \
# 0              NaN  CPF3000A  1/2" X 10' "L" COPPER       NaN     19.88
# 1              NaN   CPF3001    3/4"X20' "L" COPPER      PIPE     68.09
# 2              NaN  CPF3001A    3/4"X10' "L" COPPER      PIPE     30.49
# 3  (4.5, 4.5, 8.0)   CPF3011    3/4"X20' "M" COPPER      PIPE     49.52
# 4              NaN  CPF3011A    3/4"X10' "M" COPPER      PIPE     22.17
#
#    prcmult_1  stndprice  stndmargin
# 0        1.0      19.88         0.0
# 1        1.0      68.09         0.0
# 2        1.0      30.49         0.0
# 3        1.0      49.52         0.0
# 4        1.0      22.17         0.0

# %%
final_df = final_df[['prod','descrip_1','descrip_2','total cust\'s', 'total units', 'total margin', 'no. of override orders', 'units overriden', 'PT 7 cust\'s', 'PT 7 units', 'PT 7 quartiles', 'stndcost', 'prcmult_1', 'stndprice', 'stndmargin']]

# %% [markdown]
# ## Save records of sales

# %% [markdown]
# ## <span style="color:red"> Change vendor name at end of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_sales_record.csv'
final_df.to_csv(loc, index=False)
