# %% [markdown]
# # Identify sales

# %%
import pandas as pd
from pathlib import Path
import csd as c

# %% [markdown]
# ## <span style="color:red"> Update Month in parentheses below as you update the auxiliary folder monthly

# %%
loc = Path.cwd().parent.parent / 'auxiliary (january)' / 'data' / 'generated' / 'invoice_data_2_in-scope.csv'
inv_df = pd.read_csv(loc)

# %% [markdown]
# ## All invoice lines of sales

# %% [markdown]
# ## <span style="color:red"> Change vendor number(s)

# %%
loc = Path.cwd().parent / 'data' / 'merfish_product_info.csv'
prod_info_df = pd.read_csv(loc)

# %%
unique_prod_df = prod_info_df[['prod']].drop_duplicates()

# %%
sales_df = unique_prod_df.merge(inv_df, how='inner', left_on='prod', right_on='item').drop(columns=['prod'])

# %%
sales_df.to_clipboard(index=False)

# %%
sales_df.head()
# Out:
#    whse    orderno  ordersuf  lineno   invoicedt  custno  \
# 0   801  981007725         0       3  2022-06-21  112441
# 1   801  981008070         0       6  2022-07-01  109730
# 2   801  981012717         0       1  2022-12-22  109631
# 3   801  981006017         0       3  2022-04-21  101013
# 4   801  981007484         0       4  2022-06-13  101013
#
#                         custname      item                      itemdesc unit  \
# 0  MECHANICAL INSTALLATION CORP.   CPF3114  5/8"X50' REFRIG. COIL COPPER   RL
# 1          PERFECT AIR SOLUTIONS   CPF3114  5/8"X50' REFRIG. COIL COPPER   RL
# 2           A & M HEATING & A/C,   CPF3114  5/8"X50' REFRIG. COIL COPPER   RL
# 3            BELL MECHANICAL LLC  CPF3012A       1"X10' "M" COPPER PIPE    LG
# 4            BELL MECHANICAL LLC  CPF3012A       1"X10' "M" COPPER PIPE    LG
#
#    ...  priceorigcd  pdrecno   vendno  xcost_adj      GP$    Margin    month  \
# 0  ...            O        0  86125.0    110.758  194.162  0.636764  2022-06
# 1  ...            7     2496  86125.0     55.379  108.971  0.663042  2022-07
# 2  ...            7     2496  86125.0     55.379  108.971  0.663042  2022-12
# 3  ...            2    63025  86125.0    186.150   59.600  0.242523  2022-04
# 4  ...            2    63025  86125.0    186.150   59.600  0.242523  2022-06
#
#   Exclusion   whse_name  division
# 0       NaN  All County      HVAC
# 1       NaN  All County      HVAC
# 2       NaN  All County      HVAC
# 3       NaN  All County      HVAC
# 4       NaN  All County      HVAC
#
# [5 rows x 32 columns]

# %%
sales_df.columns
# Out:
# Index(['whse', 'orderno', 'ordersuf', 'lineno', 'invoicedt', 'custno',
#        'custname', 'item', 'itemdesc', 'unit', 'unitconv', 'units', 'unitcost',
#        'replcost', 'unitprice', 'netamt', 'returnfl', 'transtype', 'prod_type',
#        'prodcat', 'cat_descrip', 'rowpointer', 'priceorigcd', 'pdrecno',
#        'vendno', 'xcost_adj', 'GP$', 'Margin', 'month', 'Exclusion',
#        'whse_name', 'division'],
#       dtype='object')

# %% [markdown]
# ## Total sales by item and total customers

# %%
"""
group sales in two stages:
    first stage by 'item' and 'custno' with 'units' aggregated by sum
    second stage by 'item' aggregating 'custno' by count and 'units' by sum
the two stages of process let us count # of customers and get total sales of each item
"""
agg_sales_pre_df = sales_df.groupby(by=['item','itemdesc','custno'],as_index=False).agg({'units':'sum','netamt':'sum','xcost_adj':'sum'})

# %%
agg_sales_pre_df.to_clipboard(index=False)

# %%
agg_sales_pre_df
# Out:
#          item                  itemdesc  custno  units   netamt   xcost_adj
# 0    CPF3000A    1/2" X 10' "L" COPPER   101013   18.0   464.76   360.35100
# 1    CPF3000A    1/2" X 10' "L" COPPER   101046    1.0    25.82    20.92825
# 2     CPF3001  3/4"X20' "L" COPPER PIPE  101013   10.0   991.40   702.41000
# 3    CPF3001A  3/4"X10' "L" COPPER PIPE  101013  118.0  5493.16  4005.09945
# 4     CPF3011  3/4"X20' "M" COPPER PIPE  101013    5.0   313.15   220.42715
# ..        ...                       ...     ...    ...      ...         ...
# 349    PVC50A    2"X10' PVC SCH40 PIPE   111261    2.0    62.12    42.65762
# 350    PVC50A    2"X10' PVC SCH40 PIPE   111965    2.0    66.40    38.69048
# 351    PVC50A    2"X10' PVC SCH40 PIPE   112441    3.0    91.80    57.20244
# 352    PVC50A    2"X10' PVC SCH40 PIPE   112601    1.0    28.56    19.06748
# 353    PVC50A    2"X10' PVC SCH40 PIPE   112985    6.0   199.20   116.07144
#
# [354 rows x 6 columns]

# %%
agg_sales_df = agg_sales_pre_df.groupby(by=['item','itemdesc'],as_index=False).agg({'custno':'count','units':'sum','netamt':'sum','xcost_adj':'sum'}).rename(columns={'custno':'total cust\'s','units':'total units'})

# %%
agg_sales_df['total margin'] = round( 100*(agg_sales_df['netamt'] - agg_sales_df['xcost_adj']) / agg_sales_df['netamt'], 2)

# %%
agg_sales_df = agg_sales_df.drop(columns=['netamt','xcost_adj'])

# %%
agg_sales_df.to_clipboard(index=False)

# %% [markdown]
# ## Sales on overrides

# %%
overrides_df = sales_df.loc[sales_df['priceorigcd'] == 'O']

# %%
overrides_df.drop(columns=['ordersuf','lineno','unit','unitconv','month','Exclusion','cat_descrip','whse_name','division'])
# Out:
#       whse    orderno   invoicedt  custno                       custname  \
# 0      801  981007725  2022-06-21  112441  MECHANICAL INSTALLATION CORP.
# 14     801  981007673  2022-06-20  112579                    RAUL RIVERA
# 16     801  981008572  2022-07-21  101354                  TOTAL COMFORT
# 17     801  981010608  2022-10-03  101354                  TOTAL COMFORT
# 24     801  981007671  2022-06-20  109698      MERCURY ENERGY MGMT. INC.
# ...    ...        ...         ...     ...                            ...
# 1512   801  981004013  2022-02-03  109648  ALL SEASONS HVAC REF LIC FILE
# 1545   801  981005316  2022-03-31  101062       SOUNDVIEW SHEETMETAL LLC
# 1549   801  981005617  2022-04-12  101062       SOUNDVIEW SHEETMETAL LLC
# 1566   801  981006434  2022-05-06  101015                   BOTTINI FUEL
# 1572   801  981006804  2022-05-19  101015                   BOTTINI FUEL
#
#          item                        itemdesc  units   unitcost  replcost  \
# 0     CPF3114    5/8"X50' REFRIG. COIL COPPER    2.0   55.37900    106.72
# 14    CPF3110  1/4" X 50' REFRIG. COIL COPPER    1.0   40.06200     39.65
# 16    CPF3110  1/4" X 50' REFRIG. COIL COPPER    1.0   40.06200     39.65
# 17    CPF3110  1/4" X 50' REFRIG. COIL COPPER    1.0   40.06200     39.65
# 24    CPF3116    7/8"X50' REFRIG. COIL COPPER   10.0  194.20428    188.99
# ...       ...                             ...    ...        ...       ...
# 1512    PVC26        3/4"X10' SCH40 PVC PIPE    10.0    6.03045      6.12
# 1545    PVC26        3/4"X10' SCH40 PVC PIPE     1.0    6.54419      6.12
# 1549    PVC26        3/4"X10' SCH40 PVC PIPE     2.0    6.54419      6.12
# 1566    PVC26        3/4"X10' SCH40 PVC PIPE    10.0    6.71920      6.12
# 1572    PVC26        3/4"X10' SCH40 PVC PIPE     1.0    6.71920      6.12
#
#       ...  transtype  prod_type  prodcat  \
# 0     ...         CS    stocked     6380
# 14    ...         CS    stocked     6380
# 16    ...         SO    stocked     6380
# 17    ...         SO    stocked     6380
# 24    ...         SO    stocked     6380
# ...   ...        ...        ...      ...
# 1512  ...         SO    stocked     7000
# 1545  ...         SO    stocked     7000
# 1549  ...         SO    stocked     7000
# 1566  ...         SO    stocked     7000
# 1572  ...         SO    stocked     7000
#
#                                 rowpointer priceorigcd  pdrecno   vendno  \
# 0     a09b5422-d97d-878a-9814-c288587bced4           O        0  86125.0
# 14    92b84891-26aa-d99e-9814-0e78a8aa975b           O        0  86125.0
# 16    be00e090-2c26-f096-9a14-a95d709fd015           O        0  86125.0
# 17    946f0448-d2f6-8d8a-9e14-7be8a00bb0f1           O        0  86125.0
# 24    91553ec0-4c02-8fb5-9814-7b771873e7cf           O        0  86125.0
# ...                                    ...         ...      ...      ...
# 1512  f24f5533-1480-56ab-9014-1a02b87aeb7b           O        0  86125.0
# 1545  f5df97dc-5b21-afbb-9314-8624508dc718           O     9348  86125.0
# 1549  9823b1d2-5018-27b4-9314-9edd883a7275           O     9348  86125.0
# 1566  f2d59bd7-e57f-baa4-9514-2aa8d80ba91f           O        0  86125.0
# 1572  e9005d9f-f23c-3487-9614-8583e0a6a985           O     9348  86125.0
#
#        xcost_adj        GP$    Margin
# 0      110.75800  194.16200  0.636764
# 14      40.06200   47.93800  0.544750
# 16      40.06200   16.58800  0.292816
# 17      40.06200   16.58800  0.292816
# 24    1942.04280  289.35720  0.129675
# ...          ...        ...       ...
# 1512    60.30450   27.19550  0.310806
# 1545     6.54419    2.87581  0.305288
# 1549    13.08838    5.75162  0.305288
# 1566    67.19200   24.20800  0.264858
# 1572     6.71920    2.42080  0.264858
#
# [94 rows x 23 columns]

# %%
agg_overrides_df = overrides_df.groupby(by=['item'],as_index=False).agg({'units':'sum'}).rename(columns={'units':'units overriden'})

# %%
agg_overrides_df
# Out:
#         item  units overriden
# 0   CPF3000A             10.0
# 1    CPF3001              5.0
# 2   CPF3001A             98.0
# 3   CPF3011A             27.0
# 4    CPF3023             50.0
# 5    CPF3110              3.0
# 6    CPF3112             80.0
# 7    CPF3114              2.0
# 8    CPF3115             36.0
# 9    CPF3116             39.0
# 10    PVC251             65.0
# 11     PVC26             34.0
# 12    PVC401              3.0
# 13      PVC5             44.0
# 14    PVC500             42.0
# 15    PVC50A             95.0

# %% [markdown]
# ## Total PT 7 sales (no overrides)

# %% [markdown]
# ## <span style="color:red"> Change vendor name in last part of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_PT_7_PRs.csv'
PT_7_PRs = pd.read_csv(loc)

# %%
PT_7_PRs = PT_7_PRs.drop_duplicates()

# %%
PT_7_sales_by_PR_df = sales_df.merge(PT_7_PRs[['prod','pdrecno']], how='inner', left_on=['item','pdrecno'], right_on=['prod','pdrecno'])

# %%
PT_7_sales_by_PR_df.head()
# Out:
#    whse    orderno  ordersuf  lineno   invoicedt  custno  \
# 0   801  981008070         0       6  2022-07-01  109730
# 1   801  981012717         0       1  2022-12-22  109631
# 2   801  981003354         0       1  2022-01-06  101006
# 3   801  981003395         0       2  2022-01-10  109698
# 4   801  981004869         0      12  2022-03-09  101013
#
#                     custname     item                        itemdesc unit  \
# 0      PERFECT AIR SOLUTIONS  CPF3114    5/8"X50' REFRIG. COIL COPPER   RL
# 1       A & M HEATING & A/C,  CPF3114    5/8"X50' REFRIG. COIL COPPER   RL
# 2  AMX COOLING & HEATING LLC  CPF3110  1/4" X 50' REFRIG. COIL COPPER   EA
# 3  MERCURY ENERGY MGMT. INC.  CPF3116    7/8"X50' REFRIG. COIL COPPER   RL
# 4        BELL MECHANICAL LLC  CPF3011        3/4"X20' "M" COPPER PIPE   LG
#
#    ...  pdrecno   vendno   xcost_adj        GP$    Margin    month  Exclusion  \
# 0  ...     2496  86125.0    55.37900  108.97100  0.663042  2022-07        NaN
# 1  ...     2496  86125.0    55.37900  108.97100  0.663042  2022-12        NaN
# 2  ...     2490  86125.0    25.79400   29.14600  0.530506  2022-01        NaN
# 3  ...     2498  86125.0  1889.90000  168.30000  0.081770  2022-01        NaN
# 4  ...     2472  86125.0   220.42715   92.72285  0.296097  2022-03        NaN
#
#     whse_name division     prod
# 0  All County     HVAC  CPF3114
# 1  All County     HVAC  CPF3114
# 2  All County     HVAC  CPF3110
# 3  All County     HVAC  CPF3116
# 4  All County     HVAC  CPF3011
#
# [5 rows x 33 columns]

# %%
PT_7_sales_by_PR_df.shape
# Out:
# (572, 33)

# %%
PT_7_sales_by_PR_df['margin by replcost'] = (PT_7_sales_by_PR_df['netamt'] - PT_7_sales_by_PR_df['replcost']*PT_7_sales_by_PR_df['units']) / PT_7_sales_by_PR_df['netamt']

# %%
# drop unnecessary columns
PT_7_sales_by_PR_df = PT_7_sales_by_PR_df.drop(columns=['orderno','ordersuf','lineno','unit','unitconv','returnfl','prod_type','prodcat','cat_descrip','rowpointer','Exclusion'])

# %%
# inspect output
PT_7_sales_by_PR_df.to_clipboard(index=False)

# %%
PT_7_no_overs_df = PT_7_sales_by_PR_df.loc[ PT_7_sales_by_PR_df['priceorigcd'] == '7']

# %%
# inspect output
PT_7_no_overs_df.to_clipboard(index=False)

# %%
"""
group sales in two stages:
    first stage by 'item' and 'custno' with 'units' aggregated by sum
    second stage by 'item' aggregating 'custno' by count and 'units' by sum
the two stages of process let us count # of customers and get total sales of each item
"""
PT_7_no_overs_agg_pre_df = PT_7_no_overs_df.groupby(by=['item','custno'],as_index=False).agg({'units':'sum'})

# %%
PT_7_no_overs_agg_pre_df.to_clipboard(index=False)

# %%
PT_7_no_overs_agg_pre_df.loc[PT_7_no_overs_agg_pre_df.duplicated(subset=['item','custno'])]
# Out:
# Empty DataFrame
# Columns: [item, custno, units]
# Index: []

# %%
PT_7_no_overs_agg_df = PT_7_no_overs_agg_pre_df.groupby(by=['item'],as_index=False).agg({'custno':'count','units':'sum'}).rename(columns={'custno':'PT 7 cust\'s', 'units':'PT 7 units'})

# %%
PT_7_no_overs_agg_df
# Out:
#        item  PT 7 cust's  PT 7 units
# 0   CPF3011            1         5.0
# 1   CPF3024            1         1.0
# 2   CPF3110            1         1.0
# 3   CPF3112            1         1.0
# 4   CPF3114            2         2.0
# 5   CPF3116            1        10.0
# 6    PVC251           95      1106.0
# 7     PVC26            8        39.0
# 8    PVC401            1        24.0
# 9      PVC5            2        16.0
# 10   PVC500           12       102.0
# 11   PVC50A           48       900.0

# %%
# make cumulative percentage stats
PT_7_no_overs_quartiles_df = PT_7_no_overs_agg_pre_df[['item','units']].groupby('item').quantile(q=[.5,1],interpolation='midpoint')

# %%
PT_7_no_overs_quartiles_df.head()
# Out:
#              units
# item
# CPF3011 0.5    5.0
#         1.0    5.0
# CPF3024 0.5    1.0
#         1.0    1.0
# CPF3110 0.5    1.0

# %%
PT_7_no_overs_quartiles_df = PT_7_no_overs_quartiles_df.reset_index()

# %%
# data frame of quartiles of sales per customer
quartile_df = pd.DataFrame([ [prod,tuple(PT_7_no_overs_quartiles_df.loc[PT_7_no_overs_quartiles_df['item'] == prod]['units'].tolist())] for prod in PT_7_no_overs_quartiles_df['item'].unique()], columns=['item','PT 7 quartiles'])

# %%
quartile_df
# Out:
#        item PT 7 quartiles
# 0   CPF3011     (5.0, 5.0)
# 1   CPF3024     (1.0, 1.0)
# 2   CPF3110     (1.0, 1.0)
# 3   CPF3112     (1.0, 1.0)
# 4   CPF3114     (1.0, 1.0)
# 5   CPF3116   (10.0, 10.0)
# 6    PVC251   (4.0, 199.0)
# 7     PVC26    (2.5, 23.0)
# 8    PVC401   (24.0, 24.0)
# 9      PVC5    (8.0, 11.0)
# 10   PVC500    (5.0, 43.0)
# 11   PVC50A   (4.0, 510.0)

# %% [markdown]
# # Standard cost, multiplier, and standard price

# %% [markdown]
# ## <span style="color:red"> Change the vendor name at end of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_product_info.csv'
cost_data_df = pd.read_csv(loc)

# %%
cost_data_df.columns
# Out:
# Index(['whse', 'vendno', 'name', 'prod', 'descrip_1', 'descrip_2', 'mfgprod',
#        'vendprod', 'pricetype', 'prodcat', 'prodcat_descrip', 'unitstock',
#        'unitsell', 'unitconv', 'listprice', 'avgcost', 'lastcost', 'replcost',
#        'replcostdt', 'stndcost', 'stndcostdt', 'priceonty', 'prcmult_1',
#        't12m_sales', 'qtyonhand', 'qtyonorder', 'stndprice'],
#       dtype='object')

# %% [markdown]
# ## <span style="color:red"> Change vendor number(s)

# %%
# pick out cost data for our vendor
specific_cost_data_df = cost_data_df.loc[ ((cost_data_df['vendno'] == 18821) | (cost_data_df['vendno'] == 86125)) ]

# %%
specific_cost_data_df_cleaned = specific_cost_data_df[['prod','descrip_1','descrip_2','stndcostdt','stndcost','prcmult_1','stndprice','vendno']].sort_values(by=['prod','stndcostdt','stndcost']).drop_duplicates(subset=['prod'],keep='last')

# %%
specific_cost_data_df_cleaned['stndmargin'] = round((specific_cost_data_df_cleaned['prcmult_1']*100 - 100) / specific_cost_data_df_cleaned['prcmult_1'], 2)

# %%
specific_cost_data_df_cleaned
# Out:
#         prod                 descrip_1        descrip_2  stndcostdt  stndcost  \
# 38   BLK2100  1/2" X 21' TC BLACK PIPE              NaN  2021-09-17   17.2400
# 37  BLK2100A  1/2" X 10' TC BLACK PIPE              NaN  2021-08-16   17.2400
# 39   BLK2101    3/4"X21' TC BLACK PIPE              NaN  2021-08-16   34.9800
# 40  BLK2101A    3/4"X10' TC BLACK PIPE              NaN  2021-08-16   18.0900
# 36  BLK2102A      1"X10' TC BLACK PIPE              NaN  2021-10-13   23.1400
# 2    BLK2103       1-1/4"X21' TC BLACK             PIPE  2021-08-16   54.8700
# 11   CPF3000     1/2 "X 20' "L" COPPER             PIPE  2021-11-08   41.7900
# 33  CPF3000A     1/2" X 10' "L" COPPER              NaN  2021-08-16   19.8800
# 20   CPF3001       3/4"X20' "L" COPPER             PIPE  2021-11-08   68.0900
# 22  CPF3001A       3/4"X10' "L" COPPER             PIPE  2021-08-16   30.4900
# 8    CPF3002    1"X20' "L" COPPER PIPE              NaN  2021-11-08   98.7400
# 18  CPF3002A    1"X10' "L" COPPER PIPE              NaN  2021-05-06   44.1900
# 29   CPF3006     2-1/2"X20' "L" COPPER             PIPE  2021-08-16  119.4100
# 16   CPF3011       3/4"X20' "M" COPPER             PIPE  2021-11-08   49.5200
# 30  CPF3011A       3/4"X10' "M" COPPER             PIPE  2021-08-16   22.1700
# 1    CPF3012    1"X20' "M" COPPER PIPE              NaN  2021-11-08   75.6800
# 5   CPF3012A    1"X10' "M" COPPER PIPE              NaN  2021-11-17   37.8400
# 26   CPF3013     1-1/4"X20' "M" COPPER             PIPE  2021-11-08  112.1200
# 32  CPF3013A     1-1/4"X10' "M" COPPER             PIPE  2021-08-16   50.1800
# 21   CPF3014     1-1/2"X20' "M" COPPER             PIPE  2021-08-16  107.9100
# 3    CPF3015    2"X20' "M" COPPER PIPE              NaN  2021-08-16  192.8200
# 34   CPF3020   3/8"ODX20' "ACR" COPPER             PIPE  2021-11-08   24.9900
# 6    CPF3021         1/2"OD X 20' "ACR      COPPER PIPE  2021-11-08   37.6800
# 14   CPF3022   5/8"ODX20' "ACR" COPPER             PIPE  2021-11-08   48.2900
# 24   CPF3023   3/4"ODX20' "ACR" COPPER             PIPE  2021-11-08   65.1500
# 35   CPF3024   7/8"ODX20' "ACR" COPPER             PIPE  2021-11-08   77.1500
# 10   CPF3025         1-1/8"ODX20' "ACR      COPPER PIPE  2021-11-08  110.8900
# 27   CPF3026         1-3/8"ODX20' "ACR      COPPER PIPE  2021-11-08  147.8700
# 17   CPF3027         1-5/8"ODX20' "ACR      COPPER PIPE  2021-08-16  150.2500
# 0    CPF3100       1/4" X 60' "L" COIL  COPPER (3/8"OD)  2021-08-16   39.2000
# 28  CPF3102A       3/4"X60' "L" COPPER             COIL  2021-08-16   54.3300
# 7    CPF3110   1/4" X 50' REFRIG. COIL           COPPER  2021-11-08   39.6500
# 9    CPF3111    5/16"X50' REFRIG. COIL           COPPER  2021-08-16   27.2800
# 31   CPF3112     3/8"X50' REFRIG. COIL           COPPER  2021-11-08   56.0500
# 13  CPF3112B    3/8"X50' ORANGE COATED              NaN  2021-08-16   60.5300
# 25   CPF3113   1/2" X 50' REFRIG. COIL           COPPER  2021-11-08   79.7400
# 23  CPF3113B  1/2" X 50' ORANGE COATED              NaN  2021-08-16  101.3700
# 4    CPF3114     5/8"X50' REFRIG. COIL           COPPER  2021-11-08  106.7200
# 19   CPF3115     3/4"X50' REFRIG. COIL           COPPER  2021-11-08  126.6700
# 12   CPF3116     7/8"X50' REFRIG. COIL           COPPER  2021-10-13  188.9900
# 15   CPF3117   1-1/8"X50' REFRIG. COIL           COPPER  2021-08-16  247.9500
# 48    PVC220    2"X20' PVC SCHEDULE 40             PIPE  2021-08-16   17.5300
# 65     PVC25   3/4"X20' PVC SCH40 PIPE              NaN  2022-02-24    3.4272
# 58    PVC251   3/4"X10' PVC SCH40 PIPE              NaN  2022-02-24    6.8544
# 68     PVC26   3/4"X10' SCH40 PVC PIPE              NaN  2021-10-13    6.1200
# 70    PVC320    3"X20' PVC SCHEDULE 40             PIPE  2021-08-16   29.3000
# 71    PVC401     1"X10' PVC SCH40 PIPE              NaN  2022-02-24   10.7712
# 45    PVC402      1-1/4"X10' SCH40 PVC             PIPE  2021-08-16    5.1000
# 66    PVC420    4"X20' PVC SCHEDULE 40             PIPE  2021-08-16   41.3000
# 69      PVC5     3"X20' PVC SCH40 PIPE              NaN  2022-02-24   21.5424
# 44     PVC50     2"X20' PVC SCH40 PIPE              NaN  2022-02-24   10.7100
# 74    PVC500     3"X10' PVC SCH40 PIPE              NaN  2022-02-24   43.0848
# 55    PVC50A     2"X10' PVC SCH40 PIPE              NaN  2022-02-24   21.4200
#
#     prcmult_1  stndprice  vendno  stndmargin
# 38   4.500000      77.58   86125       77.78
# 37   4.550000      78.44   86125       78.02
# 39   2.460000      86.05   86125       59.35
# 40   1.910000      34.55   86125       47.64
# 36   1.000000      23.14   86125        0.00
# 2    2.030000     111.39   86125       50.74
# 11   1.000000      41.79   86125        0.00
# 33   1.612903      32.06   86125       38.00
# 20   1.612903     109.82   86125       38.00
# 22   1.612903      49.18   86125       38.00
# 8    1.612903     159.26   86125       38.00
# 18   1.612903      71.27   86125       38.00
# 29   1.612903     192.60   86125       38.00
# 16   1.612903      79.87   86125       38.00
# 30   1.612903      35.76   86125       38.00
# 1    1.612903     122.06   86125       38.00
# 5    1.612903      61.03   86125       38.00
# 26   1.612903     180.84   86125       38.00
# 32   1.612903      80.94   86125       38.00
# 21   1.612903     174.05   86125       38.00
# 3    1.612903     311.00   86125       38.00
# 34   1.612903      40.31   86125       38.00
# 6    1.612903      60.77   86125       38.00
# 14   1.612903      77.89   86125       38.00
# 24   1.612903     105.08   86125       38.00
# 35   1.612903     124.44   86125       38.00
# 10   1.612903     178.85   86125       38.00
# 27   1.612903     238.50   86125       38.00
# 17   1.612903     242.34   86125       38.00
# 0    1.612903      63.23   86125       38.00
# 28   1.612903      87.63   86125       38.00
# 7    1.612903      63.95   86125       38.00
# 9    1.612903      44.00   86125       38.00
# 31   1.612903      90.40   86125       38.00
# 13   1.612903      97.63   86125       38.00
# 25   1.612903     128.61   86125       38.00
# 23   1.612903     163.50   86125       38.00
# 4    1.612903     172.13   86125       38.00
# 19   1.612903     204.31   86125       38.00
# 12   1.612903     304.82   86125       38.00
# 15   2.270000     562.85   86125       55.95
# 48   2.460000      43.12   86125       59.35
# 65   1.550000       5.31   18821       35.48
# 58   1.587302      10.88   18821       37.00
# 68   1.587302       9.71   86125       37.00
# 70   1.612903      47.26   86125       38.00
# 71   1.694915      18.26   18821       41.00
# 45   1.820000       9.28   86125       45.05
# 66   1.612903      66.61   86125       38.00
# 69   1.612903      34.75   18821       38.00
# 44   1.612903      17.27   18821       38.00
# 74   1.612903      69.49   18821       38.00
# 55   1.587302      34.00   18821       37.00

# %% [markdown]
# ## Put everything together

# %%
merge_1_df = agg_sales_df.merge(agg_overrides_df, how='left', on='item')

# %%
merge_2_df = merge_1_df.merge(PT_7_no_overs_agg_df, how='left', on='item')

# %%
merge_3_df = merge_2_df.merge(quartile_df, how='left', on='item')

# %%
merge_4_df = merge_3_df.merge(specific_cost_data_df_cleaned, how='outer', left_on='item', right_on='prod')

# %%
final_df = merge_4_df.drop(columns='item')

# %%
final_df.columns
# Out:
# Index(['itemdesc', 'total cust's', 'total units', 'total margin',
#        'units overriden', 'PT 7 cust's', 'PT 7 units', 'PT 7 quartiles',
#        'prod', 'descrip_1', 'descrip_2', 'stndcostdt', 'stndcost', 'prcmult_1',
#        'stndprice', 'vendno', 'stndmargin'],
#       dtype='object')

# %%
final_df.head()
# Out:
#                    itemdesc  total cust's  total units  total margin  \
# 0    1/2" X 10' "L" COPPER            2.0         19.0         22.28
# 1  3/4"X20' "L" COPPER PIPE           1.0         10.0         29.15
# 2  3/4"X10' "L" COPPER PIPE           1.0        118.0         27.09
# 3  3/4"X20' "M" COPPER PIPE           1.0          5.0         29.61
# 4  3/4"X10' "M" COPPER PIPE           2.0         44.0         19.70
#
#    units overriden  PT 7 cust's  PT 7 units PT 7 quartiles      prod  \
# 0             10.0          NaN         NaN            NaN  CPF3000A
# 1              5.0          NaN         NaN            NaN   CPF3001
# 2             98.0          NaN         NaN            NaN  CPF3001A
# 3              NaN          1.0         5.0     (5.0, 5.0)   CPF3011
# 4             27.0          NaN         NaN            NaN  CPF3011A
#
#                descrip_1 descrip_2  stndcostdt  stndcost  prcmult_1  \
# 0  1/2" X 10' "L" COPPER       NaN  2021-08-16     19.88   1.612903
# 1    3/4"X20' "L" COPPER      PIPE  2021-11-08     68.09   1.612903
# 2    3/4"X10' "L" COPPER      PIPE  2021-08-16     30.49   1.612903
# 3    3/4"X20' "M" COPPER      PIPE  2021-11-08     49.52   1.612903
# 4    3/4"X10' "M" COPPER      PIPE  2021-08-16     22.17   1.612903
#
#    stndprice  vendno  stndmargin
# 0      32.06   86125        38.0
# 1     109.82   86125        38.0
# 2      49.18   86125        38.0
# 3      79.87   86125        38.0
# 4      35.76   86125        38.0

# %%
final_df['new stndcost'] = None
final_df['stndcost no adjust.'] = None
final_df['new stndprice'] = None
final_df['new stndmargin'] = None
final_df['move rate'] = None
final_df['margin change'] = None

# %%
final_df = final_df[['prod','descrip_1', 'descrip_2', 'total cust\'s', 'total units', 'total margin', 'units overriden',
                     'PT 7 cust\'s', 'PT 7 units', 'PT 7 quartiles', 'stndcost', 'stndprice', 'stndmargin', 'new stndcost',
                     'stndcost no adjust.', 'new stndprice', 'new stndmargin', 'move rate', 'margin change']]

# %% [markdown]
# ## Save records of sales

# %% [markdown]
# ## <span style="color:red"> Change vendor name at end of file path

# %%
loc = Path.cwd().parent / 'data' / 'merfish_sales_record.csv'
final_df.to_csv(loc, index=False)
